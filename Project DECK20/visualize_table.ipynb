# %% [markdown]
# ![image.png](attachment:1e18a66d-4a2f-4103-ac2d-5d372e2fdd3a.png)

# %% [markdown]
# ![image.png](attachment:2da78e24-5deb-433e-9e2d-233453bf2946.png)

# %% [markdown]
# ![image.png](attachment:ab7c37b9-ae47-4673-9bb7-47b97ed2accc.png)
